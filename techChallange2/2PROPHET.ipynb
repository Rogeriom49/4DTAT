# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score
from prophet.plot import plot_plotly, plot_components_plotly
from prophet.diagnostics import performance_metrics
from prophet.diagnostics import cross_validation

# %%
df = pd.read_csv('datasets/Ibovespa14anos.csv',parse_dates=['Data'])
display(df.head(20))
# Out:
# C:\Users\rpjun\AppData\Local\Temp\ipykernel_7412\3243731926.py:1: UserWarning:
#
# Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#          Data   Último  Abertura   Máxima   Mínima    Vol.    Var%
# 0  2024-05-24  124.306   124.731  125.257  124.259   9,21M  -0,34%
# 1  2024-05-23  124.729   125.650  125.665  124.431   9,99M  -0,73%
# 2  2024-05-22  125.650   127.412  127.412  125.524  12,40M  -1,38%
# 3  2024-05-21  127.412   127.754  128.272  127.205   9,14M  -0,27%
# 4  2024-05-20  127.751   128.151  128.730  127.488   9,34M  -0,31%
# 5  2024-05-17  128.151   128.280  128.464  127.696  10,26M  -0,10%
# 6  2024-05-16  128.284   128.029  128.965  127.922   9,86M   0,20%
# 7  2024-05-15  128.028   128.514  128.646  127.029  10,86M  -0,38%
# 8  2024-05-14  128.515   128.155  128.965  127.962  11,89M   0,28%
# 9  2024-05-13  128.155   127.600  128.669  127.599   8,92M   0,44%
# 10 2024-05-10  127.600   128.188  129.022  127.467  12,57M  -0,46%
# 11 2024-05-09  128.188   129.468  129.468  127.376  13,37M  -1,00%
# 12 2024-05-08  129.481   129.210  129.564  128.048   9,79M   0,21%
# 13 2024-05-07  129.210   128.466  129.745  128.464  10,18M   0,58%
# 14 2024-05-06  128.466   128.506  129.181  128.294   8,78M  -0,03%
# 15 2024-05-03  128.509   127.130  128.787  127.130  12,80M   1,09%
# 16 2024-05-02  127.122   125.926  127.670  125.926  11,55M   0,95%
# 17 2024-04-30  125.924   127.352  127.352  125.856  10,89M  -1,12%
# 18 2024-04-29  127.352   126.527  127.352  126.467   8,39M   0,65%
# 19 2024-04-26  126.526   124.651  126.826  124.651   8,90M   1,51%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3566 entries, 0 to 3565
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Data      3566 non-null   datetime64[ns]
#  1   Último    3566 non-null   float64
#  2   Abertura  3566 non-null   float64
#  3   Máxima    3566 non-null   float64
#  4   Mínima    3566 non-null   float64
#  5   Vol.      3565 non-null   object
#  6   Var%      3566 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 195.1+ KB

# %%
df_data = df[['Data','Último']]

# %%
df_data.rename(columns={'Data':'ds','Último':'y'},inplace=True)
# Out:
# C:\Users\rpjun\AppData\Local\Temp\ipykernel_7412\2873202314.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_data.head()
# Out:
#           ds        y
# 0 2024-05-24  124.306
# 1 2024-05-23  124.729
# 2 2024-05-22  125.650
# 3 2024-05-21  127.412
# 4 2024-05-20  127.751

# %%
model = Prophet(interval_width=0.95)

# %%
model.fit(df_data)
# Out:
# 21:02:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:50 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=7, freq='D')
future.head()
# Out:
#           ds
# 0 2010-01-04
# 1 2010-01-05
# 2 2010-01-06
# 3 2010-01-07
# 4 2010-01-08

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds        yhat  yhat_lower  yhat_upper
# 3568 2024-05-27  118.416070  106.337982  131.396579
# 3569 2024-05-28  118.425716  106.383650  131.153316
# 3570 2024-05-29  118.437488  105.322273  131.275631
# 3571 2024-05-30  118.451362  106.005132  130.450759
# 3572 2024-05-31  118.502985  105.854570  131.126828

# %%
plot_plotly(model, forecast)

# %%
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '30 days')
df_cv.head()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]21:02:51 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:51 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 1/25 [00:00<00:09,  2.47it/s]21:02:51 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:52 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 2/25 [00:00<00:08,  2.71it/s]21:02:52 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:52 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 3/25 [00:01<00:08,  2.75it/s]21:02:52 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:52 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 4/25 [00:01<00:07,  2.63it/s]21:02:52 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:53 - cmdstanpy - INFO - Chain [1] done processing
#  20%|██        | 5/25 [00:01<00:06,  3.02it/s]21:02:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:53 - cmdstanpy - INFO - Chain [1] done processing
#  24%|██▍       | 6/25 [00:02<00:06,  2.92it/s]21:02:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:53 - cmdstanpy - INFO - Chain [1] done processing
#  28%|██▊       | 7/25 [00:02<00:06,  2.72it/s]21:02:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:54 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 8/25 [00:03<00:06,  2.44it/s]21:02:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:54 - cmdstanpy - INFO - Chain [1] done processing
#  36%|███▌      | 9/25 [00:03<00:06,  2.33it/s]21:02:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:55 - cmdstanpy - INFO - Chain [1] done processing
#  40%|████      | 10/25 [00:03<00:06,  2.33it/s]21:02:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:55 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 11/25 [00:04<00:06,  2.03it/s]21:02:56 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:56 - cmdstanpy - INFO - Chain [1] done processing
#  48%|████▊     | 12/25 [00:05<00:07,  1.72it/s]21:02:56 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:57 - cmdstanpy - INFO - Chain [1] done processing
#  52%|█████▏    | 13/25 [00:06<00:07,  1.64it/s]21:02:57 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:58 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▌    | 14/25 [00:06<00:07,  1.48it/s]21:02:58 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:59 - cmdstanpy - INFO - Chain [1] done processing
#  60%|██████    | 15/25 [00:08<00:08,  1.17it/s]21:02:59 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:00 - cmdstanpy - INFO - Chain [1] done processing
#  64%|██████▍   | 16/25 [00:08<00:07,  1.26it/s]21:03:00 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:00 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 17/25 [00:09<00:05,  1.37it/s]21:03:00 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:01 - cmdstanpy - INFO - Chain [1] done processing
#  72%|███████▏  | 18/25 [00:09<00:04,  1.49it/s]21:03:01 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:01 - cmdstanpy - INFO - Chain [1] done processing
#  76%|███████▌  | 19/25 [00:10<00:03,  1.55it/s]21:03:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:02 - cmdstanpy - INFO - Chain [1] done processing
#  80%|████████  | 20/25 [00:11<00:03,  1.57it/s]21:03:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:03 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 21/25 [00:11<00:02,  1.55it/s]21:03:03 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:03 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 22/25 [00:12<00:02,  1.49it/s]21:03:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:04 - cmdstanpy - INFO - Chain [1] done processing
#  92%|█████████▏| 23/25 [00:13<00:01,  1.35it/s]21:03:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:05 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 24/25 [00:14<00:00,  1.21it/s]21:03:05 - cmdstanpy - INFO - Chain [1] start processing
# 21:03:06 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 25/25 [00:15<00:00,  1.62it/s]
#           ds       yhat  yhat_lower  yhat_upper       y     cutoff
# 0 2012-06-27  54.950830   51.917275   58.086488  53.109 2012-06-26
# 1 2012-06-28  54.841285   52.021593   57.738299  52.652 2012-06-26
# 2 2012-06-29  54.719375   51.476393   57.653526  54.355 2012-06-26
# 3 2012-07-02  54.537351   51.288899   57.677183  54.693 2012-06-26
# 4 2012-07-03  54.461175   51.636587   57.494584  55.780 2012-06-26

# %%
df_p = performance_metrics(df_cv)
df_p.tail(30)
# Out:
#    horizon        mse      rmse       mae      mape     mdape     smape  \
# 0   4 days  64.722873  8.045053  6.093203  0.080842  0.075657  0.078773
# 1   5 days  73.235229  8.557758  6.528238  0.085586  0.078976  0.082731
# 2   6 days  70.132106  8.374491  6.361311  0.081714  0.071494  0.078943
# 3   7 days  64.009047  8.000565  5.912527  0.074790  0.064572  0.072504
# 4   8 days  52.395438  7.238469  5.345756  0.066431  0.060257  0.065658
# 5   9 days  44.110701  6.641589  5.034479  0.062908  0.049702  0.063405
# 6  10 days  43.810237  6.618930  5.203684  0.065752  0.052365  0.066265
# 7  11 days  56.448500  7.513222  5.971447  0.075914  0.065776  0.075698
# 8  12 days  65.224567  8.076173  6.501515  0.081583  0.069292  0.080509
# 9  13 days  70.350649  8.387529  6.902426  0.085350  0.075477  0.083480
# 10 14 days  68.461460  8.274144  6.807070  0.082946  0.072602  0.081337
# 11 15 days  59.573937  7.718415  6.281944  0.076414  0.060424  0.076072
# 12 16 days  56.598978  7.523229  6.057273  0.074111  0.055224  0.074789
# 13 17 days  60.363513  7.769396  6.233790  0.077955  0.055534  0.078240
# 14 18 days  73.625489  8.580530  6.922800  0.085422  0.073612  0.085471
# 15 19 days  69.468048  8.334749  6.707823  0.083301  0.061475  0.082916
# 16 20 days  68.097616  8.252128  6.661948  0.082128  0.060401  0.080957
# 17 21 days  62.122223  7.881765  6.442207  0.079371  0.064739  0.078296
# 18 22 days  60.569000  7.782609  6.276476  0.076585  0.063555  0.076792
# 19 23 days  67.554391  8.219148  6.526638  0.079322  0.066784  0.079713
# 20 24 days  72.553371  8.517827  6.712635  0.084659  0.064429  0.084416
# 21 25 days  87.889559  9.374943  7.375358  0.093255  0.073140  0.092550
# 22 26 days  82.477066  9.081689  7.278079  0.092917  0.072985  0.092421
# 23 27 days  79.899943  8.938677  7.280133  0.091800  0.077533  0.090606
# 24 28 days  76.507826  8.746875  7.286144  0.089769  0.080332  0.088967
# 25 29 days  71.514248  8.456610  6.862776  0.084740  0.077533  0.085359
# 26 30 days  76.168325  8.727447  7.071123  0.089258  0.080234  0.090694
#
#     coverage
# 0   0.600000
# 1   0.600000
# 2   0.680000
# 3   0.770588
# 4   0.834118
# 5   0.816250
# 6   0.742353
# 7   0.640000
# 8   0.587778
# 9   0.572222
# 10  0.611250
# 11  0.691765
# 12  0.700000
# 13  0.643529
# 14  0.556471
# 15  0.583529
# 16  0.630588
# 17  0.672500
# 18  0.666667
# 19  0.613333
# 20  0.540000
# 21  0.473333
# 22  0.471250
# 23  0.521176
# 24  0.540000
# 25  0.560000
# 26  0.520000

# %%
df_new = df_data.sort_index(ascending=False)

# %%
df_new.head()
# Out:
#              ds       y
# 3565 2010-01-04  70.045
# 3564 2010-01-05  70.240
# 3563 2010-01-06  70.729
# 3562 2010-01-07  70.451
# 3561 2010-01-08  70.263

# %%
metric_df = forecast.set_index('ds')[['yhat']].join(df_new.set_index('ds').y).reset_index()

# %%
metric_df.dropna(inplace=True)

# %%
r2_score(metric_df.y, metric_df.yhat)
# Out:
# 0.9404032692185523

# %%
mean_squared_error(metric_df.y, metric_df.yhat)
# Out:
# 40.66810832836686

# %%
mean_absolute_error(metric_df.y, metric_df.yhat)
# Out:
# 4.618073597368348
